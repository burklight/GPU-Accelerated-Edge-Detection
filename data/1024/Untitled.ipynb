# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

img = mpimg.imread('../512/img1.jpg')     
gray = rgb2gray(img)    
plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.show()

gray.shape
# Out:
# (512, 512)

# %%
np.savetxt(fname='../512/img5.txt', X = gray, delimiter=' ')

# %%
a = np.loadtxt('../512/img1.txt',delimiter=',',newline=',')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-fa02e79b6415> in <module>()
# ----> 1 a = np.loadtxt('../512/img1.txt',delimiter=',',newline=',')
#
# TypeError: loadtxt() got an unexpected keyword argument 'newline'

# %%
print(a.shape)
plt.imshow(a, cmap='gray')
plt.show()
# Out:
# (512, 512)

# %%
b = np.array([[2,4,5,4,2],[4,9,12,9,4],[5,12,15,12,5],[4,9,12,9,4],[2,4,5,4,2]]) / 159.0
c = np.zeros((512,512))

# %%
sc.convolve(input=a, weights=b, output=c)

# %%
plt.imshow(c,cmap='gray')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1791a4503e5> in <module>()
# ----> 1 plt.imshow(c,cmap='gray')
#       2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
c
# Out:
# array([[146.91066038, 149.89315723, 153.21845912, ..., 153.30948428,
#         151.48258491, 149.95656604],
#        [151.53959119, 154.3382956 , 157.12818868, ..., 156.76290566,
#         154.74784906, 153.03354088],
#        [158.31055975, 160.7121195 , 162.50725786, ..., 162.47996855,
#         160.26568553, 158.29636478],
#        ...,
#        [143.32701258, 145.78863522, 147.81603145, ..., 133.71909434,
#         147.10924528, 150.31433962],
#        [141.61757862, 150.87736478, 161.15851572, ...,  99.58754088,
#         108.04573585, 110.16471069],
#        [126.95751572, 142.0641195 , 159.7705283 , ...,  76.25733333,
#          81.65193711,  83.98062893]])
