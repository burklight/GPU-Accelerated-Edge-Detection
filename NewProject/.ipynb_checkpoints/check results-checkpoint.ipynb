# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import scipy.ndimage as sc

def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

# %%
img = mpimg.imread('./512/img1.jpg')     
gray = rgb2gray(img).astype(int)   
plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.show()

# %%
folders = ['./512/','./1024/','./2048/']

# %%
dirImg = ''
dirTxt = ''
for folder in folders:
    for i in range(5):
        dirImg = folder + 'img' + str(i+1) + '.jpg'
        img = mpimg.imread(dirImg)     
        gray = rgb2gray(img).astype(int)   
        plt.imshow(gray, cmap = plt.get_cmap('gray'))
        plt.show()
        dirTxt = folder + 'img' + str(i+1) + '.txt'
        np.savetxt(fname=dirTxt, X=gray, delimiter=',',newline=',',fmt='%d')

# %%
# ?np.savetxt

# %%
a = np.loadtxt('./512/img3.txt',delimiter=',').astype(int)
b = np.array([[2,4,5,4,2],[4,9,12,9,4],[5,12,15,12,5],[4,9,12,9,4],[2,4,5,4,2]]) / 159.0
c = np.zeros((512,512))
sc.convolve(input=a, weights=b, output=c)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-336ce59f3565> in <module>()
# ----> 1 a = np.loadtxt('./512/img3.txt',delimiter=',').astype(int)
#       2 b = np.array([[2,4,5,4,2],[4,9,12,9,4],[5,12,15,12,5],[4,9,12,9,4],[2,4,5,4,2]]) / 159.0
#       3 c = np.zeros((512,512))
#       4 sc.convolve(input=a, weights=b, output=c)
#
# ~/.local/lib/python3.5/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding)
#    1090         # converting the data
#    1091         X = None
# -> 1092         for x in read_data(_loadtxt_chunksize):
#    1093             if X is None:
#    1094                 X = np.array(x, dtype)
#
# ~/.local/lib/python3.5/site-packages/numpy/lib/npyio.py in read_data(chunk_size)
#    1017
# ...

# %%
plt.imshow(a,cmap='gray')
plt.show()
plt.imshow(c,cmap='gray')
plt.show()

# %%
a
# Out:
# array([[ 91,  91,  90, ..., 104, 107, 109],
#        [ 90,  90,  89, ..., 105, 107, 109],
#        [ 88,  88,  87, ..., 105, 107, 109],
#        ...,
#        [ 99,  99, 100, ...,  37,  38,  39],
#        [102, 101, 102, ...,  28,  30,  31],
#        [104, 104, 104, ...,  24,  25,  27]])

# %%
c
# Out:
# array([[14346., 14291., 14187., ..., 16672., 16949., 17144.],
#        [14204., 14149., 14047., ..., 16686., 16950., 17136.],
#        [13969., 13915., 13818., ..., 16711., 16951., 17119.],
#        ...,
#        [15856., 15893., 15971., ...,  5966.,  6051.,  6109.],
#        [16124., 16153., 16224., ...,  4909.,  5069.,  5176.],
#        [16324., 16345., 16407., ...,  4264.,  4456.,  4583.]])

# %%
# ?np.savetxt

# %%
img = mpimg.imread('./data/512/img3.jpg')     
gray = rgb2gray(img).astype(int)

# %%
folders = ['512','1024','2048']
dirImg = ''
dirRes = ''
for folder in folders:
    for i in range(5):
        dirImg = './data/' + folder + '/img' + str(i+1) + '.jpg'
        dirRes = './data/resulting_images/' + folder + '/res' + str(i+1) + '.jpg'
        N = int(folder)
        img = mpimg.imread(dirImg)     
        gray = rgb2gray(img).astype(int)
        b = np.array([[0, 1, 0],[1,-4,1],[0,1,0]])
        g = np.array([[2,4,5,4,2],[4,9,12,9,4],[5,12,15,12,5],[4,9,12,9,4],[2,4,5,4,2]]) / 159
        c = np.zeros((N, N))
        d = np.zeros((N, N))
        sc.convolve(input=gray, weights=g, output=c)
        c = c.astype(int)
        sc.convolve(input=c, weights=b, output=d)
        d = np.where(d>5,0,1)
        fig, ax = plt.subplots(figsize=(20,20))
        ax.imshow(d,cmap='binary')
        plt.savefig(dirRes)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9335b742b6cf> in <module>()
#       6         dirImg = './data/' + folder + 'img' + str(i+1) + '.jpg'
#       7         dirRes = './data/resulting_images/' + folder + 'res' + str(i+1) + '.jpg'
# ----> 8         N = int(folder)
#       9         img = mpimg.imread(dirImg)
#      10         gray = rgb2gray(img).astype(int)
#
# ValueError: invalid literal for int() with base 10: '512/'

# %%
#b = np.array([[0, 1, 0],[1,-4,1],[0,1,0]])
g = np.array([[2,4,5,4,2],[4,9,12,9,4],[5,12,15,12,5],[4,9,12,9,4],[2,4,5,4,2]]) / 159
b = np.array([[-1,-1,-1,],[-1,8,-1],[-1,-1,-1]])

c = np.zeros((512,512))
d = np.zeros((512,512))
sc.convolve(input=gray, weights=g, output=c)
c = c.astype(int)
sc.convolve(input=c, weights=b, output=d)
print(gray[5,5:10])
print(c[5,5:10])
print(d[5,5:10])

d = np.where(d>5,0,1)
fig, ax = plt.subplots(figsize=(20,20))
ax.imshow(d,cmap='binary')
# Out:
# [83 84 84 84 84]
# [83 83 84 84 83]
# [ 0. -3.  3.  2. -4.]

# %%
fig, ax = plt.subplots(figsize=(20,20))
ax.imshow(gray,cmap='gray')
fig, ax = plt.subplots(figsize=(20,20))
ax.imshow(d,cmap='binary')

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('data/2048/img1.jpg',0)
edges = cv2.Canny(img,100,200)
 
    
fig, ax = plt.subplots(figsize=(20,20))
ax.imshow(img,cmap='gray')
fig, ax = plt.subplots(figsize=(20,20))
ax.imshow(edges,cmap='gray') 
 
plt.show()

# %%
a = np.loadtxt('./tests/edgeEx.txt',delimiter=',')
print(a[5,5:10])
# Out:
# [0. 0. 0. 0. 0.]

# %%
a = np.where(a > 5, 0,1)

# %%
fig, ax = plt.subplots(figsize=(25,25))
ax.imshow(a,cmap="binary")
plt.show()

# %%
np.sum(a == b)
# Out:
# 4170163

# %%
np.size(a)
# Out:
# 4194304

# %%
gauss = np.random.normal(loc=0, scale=1, size=(3,3))

# %%
g = np.array([[9,12,9],[12,15,12],[9,12,9]])

# %%
np.sum(g)
# Out:
# 99
